# %% [markdown]
# <a href="https://colab.research.google.com/github/nazmus007/transformers_test/blob/main/electra_ghosh_run1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qq transformers
# Out:
#      |████████████████████████████████| 4.2 MB 7.2 MB/s
#      |████████████████████████████████| 596 kB 33.4 MB/s
#      |████████████████████████████████| 6.6 MB 61.2 MB/s
#      |████████████████████████████████| 86 kB 6.7 MB/s

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import transformers

from transformers import BertModel, BertTokenizer, AdamW, get_linear_schedule_with_warmup, BertForSequenceClassification

import torch
import re
import numpy as np
import pandas as pd

import seaborn as sns

from pylab import rcParams

import matplotlib.pyplot as plt

from matplotlib import rc

from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix, classification_report

from collections import defaultdict

from textwrap import wrap

from torch import nn, optim

from torch.utils.data import Dataset, DataLoader

# %%
import torch.nn.functional as F

# %%
df_train = pd.read_csv("./drive/MyDrive/datasets/cleaned_ghosh_train_may22.csv")
df_train.head()
# Out:
#        type  Label                                              Tweet
# 0  TrainSen      0  05 really taught me a valuable lesson I am nev...
# 1  TrainSen      0   Never had a voice to protest, so you fed me s...
# 2  TrainSen      0        Rest in peace & love to you and your family
# 3  TrainSen      0  100 days until Christmas! 🌲 too soon not ready...
# 4  TrainSen      0    yay! Ca not wait to be reunited with you hun...

# %%
df_test= pd.read_csv("./drive/MyDrive/datasets/cleaned_ghosh_test_may22.csv")

# %%
df_val = pd.read_csv("./drive/MyDrive/datasets/cleaned_ghosh_dev_may22.csv")

# %%
# !pip install demoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting demoji
#   Downloading demoji-1.1.0-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 934 kB/s
# Installing collected packages: demoji
# Successfully installed demoji-1.1.0

# %%
import demoji
def demoji_text(text):
  d= demoji.findall(text)
  return d

# %%
df_train['emoji_list'] = df_train['Tweet'].apply(demoji_text)

# %%
f= list(filter(None, df_train['emoji_list']))

# %%
print(f)
# Out:
# [{'🌲': 'evergreen tree'}, {'😂': 'face with tears of joy'}, {'😂': 'face with tears of joy'}, {'😍': 'smiling face with heart-eyes'}, {'😩': 'weary face'}, {'😍': 'smiling face with heart-eyes', '😘': 'face blowing a kiss', '😁': 'beaming face with smiling eyes', '🍗': 'poultry leg', '✊': 'raised fist', '🌽': 'ear of corn', '🍴': 'fork and knife'}, {'💫': 'dizzy', '✨': 'sparkles'}, {'😭': 'loudly crying face'}, {'😭': 'loudly crying face'}, {'😴': 'sleeping face'}, {'☺': 'smiling face'}, {'🌪': 'tornado'}, {'☺️': 'smiling face'}, {'☺': 'smiling face'}, {'😂': 'face with tears of joy'}, {'😈': 'smiling face with horns', '😩': 'weary face', '😜': 'winking face with tongue'}, {'😂': 'face with tears of joy'}, {'❤️': 'red heart', '👶': 'baby', '😩': 'weary face'}, {'😍': 'smiling face with heart-eyes'}, {'😊': 'smiling face with smiling eyes'}, {'🎤': 'microphone'}, {'⚓': 'anchor', '❤️': 'red heart'}, {'❤': 'red heart'}, {'😂': 'face with tears of joy'}, {'🏈': 'american football'}, {'😘': 'face blowing a kiss'}, {'😭': 'loudly crying face'}, {'😷': 'face with medical mask'}, {'😍': 'smiling face with heart-eyes'}, {'😊': 'smiling face with smiling eyes'}, {'😩': 'weary face'}, {'😈': 'smiling face with horns', '☺️': 'smiling face'}, {'👪': 'family'}, {'😀': 'grinning face', '😍': 'smiling face with heart-eyes'}, {'😅': 'grinning face with sweat'}, {'😍': 'smiling face with heart-eyes'}, {'😭': 'loudly crying face', '😂': 'face with tears of joy'}, {'😭': 'loudly crying face'}, {'😏': 'smirking face', '😉': 'winking face'}, {'😁': 'beaming face with smiling eyes', '😍': 'smiling face with heart-eyes'}, {'😂': 'face with tears of joy'}, {'😒': 'unamused face'}, {'🌞': 'sun with face'}, {'😛': 'face with tongue', '😘': 'face blowing a kiss'}, {'❤️': 'red heart'}, {'😭': 'loudly crying face', '😍': 'smiling face with heart-eyes', '😂': 'face with tears of joy', '❤': 'red heart'}, {'😘': 'face blowing a kiss'}, {'😌': 'relieved face'}, {'😁': 'beaming face with smiling eyes'}, {'😭': 'loudly crying face'}, {'😘': 'face blowing a kiss', '😁': 'beaming face with smiling eyes', '😍': 'smiling face with heart-eyes', '❤': 'red heart'}, {'♥️': 'heart suit'}, {'😊': 'smiling face with smiling eyes'}, {'🌟': 'glowing star', '🌌': 'milky way'}, {'😃': 'grinning face with big eyes', '😄': 'grinning face with smiling eyes', '😀': 'grinning face'}, {'😭': 'loudly crying face'}, {'📖': 'open book'}, {'😘': 'face blowing a kiss', '🍇': 'grapes', '🍓': 'strawberry', '💌': 'love letter'}, {'😂': 'face with tears of joy'}, {'😲': 'astonished face'}, {'😂': 'face with tears of joy'}, {'😂': 'face with tears of joy'}, {'😑': 'expressionless face'}, {'😒': 'unamused face'}, {'❤️': 'red heart'}, {'😊': 'smiling face with smiling eyes', '☺️': 'smiling face'}, {'😡': 'pouting face'}, {'😢': 'crying face'}, {'😂': 'face with tears of joy'}, {'😉': 'winking face'}, {'❤️': 'red heart'}, {'😷': 'face with medical mask'}, {'😛': 'face with tongue'}, {'😴': 'sleeping face'}, {'😂': 'face with tears of joy'}, {'😁': 'beaming face with smiling eyes'}, {'😩': 'weary face'}, {'😭': 'loudly crying face'}, {'☀': 'sun', '♥': 'heart suit'}, {'💙': 'blue heart', '🍭': 'lollipop'}, {'❄️': 'snowflake'}, {'😝': 'squinting face with tongue'}, {'😝': 'squinting face with tongue', '😘': 'face blowing a kiss'}, {'😍': 'smiling face with heart-eyes'}, {'😂': 'face with tears of joy'}, {'😭': 'loudly crying face'}, {'😐': 'neutral face'}, {'😒': 'unamused face'}, {'😂': 'face with tears of joy'}, {'😂': 'face with tears of joy'}, {'😁': 'beaming face with smiling eyes'}, {'😊': 'smiling face with smiling eyes'}, {'😂': 'face with tears of joy'}, {'😊': 'smiling face with smiling eyes'}, {'😭': 'loudly crying face', '😜': 'winking face with tongue'}, {'😉': 'winking face'}, {'✌': 'victory hand', '😑': 'expressionless face'}, {'👪': 'family'}, {'😂': 'face with tears of joy'}, {'😐': 'neutral face'}, {'😂': 'face with tears of joy'}, {'😅': 'grinning face with sweat', '🍀': 'four leaf clover', '😜': 'winking face with tongue', '😉': 'winking face'}, {'😑': 'expressionless face'}, {'🏈': 'american foot ...

# %%
all_keys = set().union(*(d.keys() for d in f))

# %%
print(all_keys)
# Out:
# {'🐻', '🌅', '🖊', '😜', '😻', '🐷', '☀️', '🍏', '👉', '👼', '💫', '💙', '💡', '🌯', '📺', '⛪', '😆', '🌈', '🐜', '😂', '😫', '😱', '🌿', '🌌', '✂️', '👌', '👦', '➡', '🍒', '📤', '🚛', '🔐', '‼️', '😲', '🔋', '🤑', '🐯', '✏️', '🎺', '🎧', '😰', '🗽', '🍀', '🐧', '🤔', '🍂', '👦🏿', '⛷', '☃', '😥', '👎', '😈', '🇸🇸', '😇', '🔦', '🙎', '👨\u200d👩\u200d👦\u200d👦', '🍹', '🔒', '🕸', '😋', '🙏🏽', '✏', '👼🏿', '☝', '🎊', '💍', '🏦', '🐟', '💛', '😾', '📹', '🏹', '👸🏽', '💁', '✔', '✍', '🖖', '👉🏿', '🌶', '🐠', '🌪', '😎', '🍼', '📄', '🌧', '⚠️', '🍰', '👋🏻', '✝', '🎆', '👳', '🐊', '🐾', '🏆', '🐸', '👙', '♥️', '🐼', '⏳', '🗑', '☣', '🌤', '🔫', '😀', '🔊', '🚘', '💶', '👅', '🛏', '📖', '📝', '👫', '🍥', '⭕', '⚽', '🎂', '☁', '🐑', '😢', '🇨🇦', '😙', '🚮', '☁️', '☺', '🙍', '❤️', '😞', '💻', '🏿', '💸', '🌨', '💷', '😌', '💜', '🐀', '❣', '⏱', '💲', '🚶', '😓', '🙁', '©', '🌝', '🚬', '💧', '🚜', '😑', '😖', '🌠', '🐛', '🏒', '🎵', '🐔', '😔', '🆘', '🍔', '🙀', '🎮', '⛈', '📵', '🕷', '❌', '✈️', '😒', '😏', '🌳', '🔬', '🐏', '😣', '🌎', '🎄', '⭐', '✅', '🖐', '☄', '😽', '🙆🏻', '🙂', '🇪🇸', '🎙', '💕', '🌲', '👀', '🚡', '🏇', '🌂', '😡', '✔️', '🍚', '♐', '😛', '💄', '🍿', '🌴', '📈', '☺️', '👸', '📀', '🐘', '♥', '✒️', '👧', '🙌', '🍭', '👋', '🍁', '✊', '🐒', '👑', '🐥', '👪', '📻', '💈', '🍗', '🍇', '🚔', '🐰', '😿', '🐣', '🎁', '🐱', '😯', '🍅', '🌸', '🌊', '📜', '🙈', '💝', '🚑', '🌏', '👵', '🎎', '🐍', '📓', '🐮', '😁', '🌻', '🚣', '🚊', '🐳', '✂', '0⃣', '💐', '🎥', '😶', '✨', '👍', '🆗', '🎶', '❗', '🇮🇹', '☮', '✌', '🌍', '🎨', '💗', '🐚', '😄', '🇬🇧', '😤', '💌', '🌙', '🎼', '😅', '💞', '🇺🇸', '🔷', '🚫', '😦', '💎', '🅰', '👄', '👱', '🖼', '⛄', '🍵', '🔴', '⛽', '💦', '🏽', '🎅', '😴', '🏏', '🍸', '😭', '🌰', '♈', '➡️', '⏲', '🙏', '🍃', '🐿', '😮', '🈵', '😸', '🙏🏼', '💳', '🆓', '❄️', '🙇', '➰', '😚', '🎈', '🖕🏼', '😍', '🍋', '🏈', '🚽', '👍🏼', '🙃', '💣', '🎇', '👓', '🍎', '⚡', '🏡', '👠', '☹', '🔞', '💟', '📱', '😩', '1️⃣', '💁🏼', '🏃', '🚐', '😊', '💖', '😷', '😉', '😝', '👴', '🏐', '🍦', '😺', '😹', '❤', '💁🏽', '🍣', '❄', '⛸', '😳', '🌺', '🏋', '🌽', '😗', '🤐', '❓', '⛵', '👒', '🗿', '🕑', '🚗', '™', '😧', '🚂', '🚲', '🔓', '🍾', '👨\u200d👩\u200d👧\u200d👧', '🍓', '🎤', '🗣', '☹️', '🐗', '👩', '👆', '🙌🏼', '🐨', '💓', '🎉', '💵', '😐', '👶', '⚫', '🎯', '👨', '🕰', '🅿️', '👈', '🌞', '📥', '😃', '👻', '💀', '🍍', '💪', '🌬', '👗', '🌼', '👿', '🍫', '😠', '👐', '🍕', '🎑', '😕', '💋', '💩', '✌️', '🤕', '🚙', '🔱', '👲', '🦃', '🏥', '🏵', '🙊', '🔕', '☀', '🍑', '✋', '🎹', '🍟', '☔', '🔮', '🆙', '🎭', '🚌', '🍝', '👔', '🍆', '🌃', '☝️', '🍴', '✖', '☕', '🌟', '😘', '😪', '💑', '🍺', '⚓', '🔥', '⬆️', '🚪', '🌵', '👂', '😟', '😨', '🦄', '🏰', '🇯🇵', '🙄', '🐅', '😼', '🌀', '👎🏼', '®', '💯', '🆒', '🍻'}

# %%
len(all_keys)
# Out:
# 453

# %%
# !pip install sentencepiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 4.3 MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.96

# %%
PRE_TRAINED_MODEL_NAME = 'google/electra-base-discriminator'

# %%
from transformers import ElectraTokenizer

tokenizer = ElectraTokenizer.from_pretrained(PRE_TRAINED_MODEL_NAME)
tokenizer.add_tokens(['⭕', '♐', '👋', '👴', '🤔', '😳', '✔', '🎶', '😂', '😪', '⛽', '😤', '🏋', '💌', '🌏', '♥', '🎙', '💐', '🏇', '☃', '👑', '📄', '🙁', '🐊', '🌸', '☹', '💦', '⏲', '🙏🏽', '😉', '🍅', '🎮', '📹', '😄', '🎉', '😩', '😮', '🍂', '🙎', '😟', '😫', '🔫', '🙏', '😀', '⚡', '💁', '😅', '👎', '®', '❄', '🌧', '😌', '🏹', '✏️', '👍', '⏳', '💸', '👦', '🏽', '😖', '👼', '🐥', '🐜', '🌊', '😼', '✂️', '😰', '🍝', '💀', '🍿', '🙇', '🚣', '💎', '😍', '🍋', '👲', '🙌🏼', '🔒', '🌟', '📜', '💋', '⚽', '☀', '👋🏻', '🌌', '🏵', '🍀', '🚊', '🍣', '😊', '👳', '🙃', '😒', '🍻', '🏦', '📻', '🙄', '👩', '🌲', '🍏', '😞', '🔋', '👉', '🐸', '🙆🏻', '🆓', '🔮', '🍦', '💝', '🆙', '🚛', '😆', '☕', '🏰', '🆗', '🐣', '🌰', '🤑', '🔦', '🕸', '👅', '🅰', '🌈', '🎼', '🌝', '❗', '🔴', '🚐', '🌎', '😋', '🍟', '🌵', '💁🏼', '✖', '🍰', '🍹', '💷', '🚮', '🍇', '✅', '🏈', '👧', '👎🏼', '🤕', '👐', '🔬', '™', '🚬', '🚌', '🐼', '🚂', '👱', '📝', '‼️', '🌙', '🖊', '🍕', '😘', '💕', '🍗', '🇸🇸', '👂', '💖', '📈', '🏐', '⛄', '♥️', '🍸', '👿', '🎅', '🐱', '🤐', '🚜', '🐨', '🍚', '🎭', '⏱', '🚲', '➰', '⛪', '🍒', '😸', '🙍', '💯', '😃', '🎨', '💲', '🔷', '🗽', '👒', '🍴', '😣', '👫', '🚙', '🙂', '💈', '👈', '🐅', '🍁', '📓', '😢', '👉🏿', '🈵', '💄', '🍫', '💙', '🐍', '⚠️', '🖖', '👆', '✍', '🍑', '⛷', '♈', '🐑', '😻', '🍾', '🍍', '🎈', '😗', '✒️', '🖼', '👗', '👨', '😝', '😾', '📥', '🐧', '🌳', '❤', '😚', '🎄', '👵', '👸🏽', '➡️', '✂', '😐', '😎', '💛', '👨\u200d👩\u200d👦\u200d👦', '⬆️', '©', '❌', '⚓', '🏡', '🚡', '😡', '😱', '📀', '⛵', '🐿', '😓', '😁', '🐘', '🍔', '⭐', '🐾', '🏒', '🍼', '🎯', '🐚', '😔', '❣', '🦃', '💧', '👍🏼', '🆒', '🐟', '💍', '💪', '🚗', '💓', '😽', '🖐', '😿', '💑', '😴', '🚫', '👀', '❄️', '🍃', '✌', '🐷', '🌪', '😹', '🔓', '🌺', '😈', '😛', '🌴', '☄', '🐳', '💗', '🌻', '🐀', '😨', '😙', '💶', '😑', '🐰', '🇪🇸', '🔐', '⛈', '😶', '🇮🇹', '❓', '😦', '🌼', '🌤', '🖕🏼', '➡', '🌨', '⛸', '👪', '📖', '🍎', '👸', '🐗', '🆘', '🗣', '🎁', '🌯', '🏥', '🐏', '🔕', '😧', '🕷', '☝️', '😕', '🇯🇵', '👓', '🔥', '🍵', '✨', '🔱', '📵', '📺', '💳', '🇺🇸', '👄', '💫', '🚑', '😲', '🎆', '🙀', '😜', '📱', '🌿', '❤️', '🍭', '✏', '☺', '⚫', '🎺', '🌍', '🛏', '🎵', '0⃣', '🚘', '💣', '🏃', '😇', '🚪', '🎂', '😥', '😠', '😺', '🔞', '☝', '🌃', '🔊', '🏆', '🎊', '🍥', '🚶', '☁️', '🐔', '☔', '😯', '🌠', '👙', '🎤', '🌬', '✌️', '☮', '🦄', '💵', '🍺', '🍆', '🗑', '📤', '🕰', '😷', '🐛', '🌅', '✊', '🚔', '☹️', '🍓', '🙏🏼', '👠', '🐯', '☁', '🗿', '🎇', '💟', '💻', '💞', '🇨🇦', '✝', '🎧', '✔️', '🐒', '💁🏽', '🐮', '🌂', '1️⃣', '🌽', '✈️', '✋', '💡', '🙌', '👨\u200d👩\u200d👧\u200d👧', '🕑', '🌶', '🎎', '👶', '💩', '🏏', '🏿', '☺️', '🌞', '🙈', '💜', '👌', '🇬🇧', '🐠', '👼🏿', '☣', '☀️', '👻', '🎑', '🎹', '😭', '🌀', '🙊', '👦🏿', '😏', '🅿️', '🐻', '🎥', '👔', '🚽'])
# Out:
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/27.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/666 [00:00<?, ?B/s]
# 449

# %%
token_lens = []

for txt in df_train['Tweet']:
  tokens = tokenizer.encode(txt, max_length=512)
  token_lens.append(len(tokens))
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
import seaborn as sns

sns.distplot(token_lens)
plt.xlim([0, 256]);
plt.xlabel('Token count');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_train_X= list(df_train["Tweet"])
df_val_X = list(df_val["Tweet"])

# %%
y_train = list(df_train["Label"])

y_val = list(df_val["Label"])

y_test = list(df_test["Label"])

# %%
X_train_tokenized = tokenizer(df_train_X, padding=True, truncation=True, max_length=512)
X_val_tokenized = tokenizer(df_val_X, padding=True, truncation=True, max_length=512)

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels=None):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item["labels"] = torch.tensor([self.labels[idx]])
        return item

    def __len__(self):
        return len(self.encodings["input_ids"])

# %%
train_dataset = Dataset(X_train_tokenized, y_train)
val_dataset = Dataset(X_val_tokenized, y_val)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
from transformers import ElectraForSequenceClassification

model = ElectraForSequenceClassification.from_pretrained(
    "google/electra-base-discriminator", # Use the 12-layer BERT model, with an uncased vocab.
    num_labels = 2, # The number of output labels--2 for binary classification.
                    # You can increase this for multi-class tasks.   
    output_attentions = False, # Whether the model returns attentions weights.
    output_hidden_states = False, # Whether the model returns all hidden-states.
)

model.resize_token_embeddings(len(tokenizer))
# Out:
# Downloading:   0%|          | 0.00/420M [00:00<?, ?B/s]
# Some weights of the model checkpoint at google/electra-base-discriminator were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense_prediction.bias', 'discriminator_predictions.dense.weight', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense.bias']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at google/electra-base-discriminator and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Embedding(30971, 768)

# %%
model.to(device)
# Out:
# ElectraForSequenceClassification(
#   (electra): ElectraModel(
#     (embeddings): ElectraEmbeddings(
#       (word_embeddings): Embedding(30971, 768)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): ElectraEncoder(
#       (layer): ModuleList(
#         (0): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): ElectraLayer(
#           (attention): ElectraAttention(
#             (self): ElectraSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): ElectraSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): ElectraIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ElectraOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (classifier): ElectraClassificationHead(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (out_proj): Linear(in_features=768, out_features=2, bias=True)
#   )
# )

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

def compute_metrics(p):
    pred, labels = p
    pred = np.argmax(pred, axis=1)

    accuracy = accuracy_score(y_true=labels, y_pred=pred)
    recall = recall_score(y_true=labels, y_pred=pred)
    precision = precision_score(y_true=labels, y_pred=pred)
    f1 = f1_score(y_true=labels, y_pred=pred)


    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1}

# %%
output_dir='./drive/MyDrive/savedmodel_meta/ghosh_electra'

# %%
from transformers import TrainingArguments, Trainer

args = TrainingArguments(
    output_dir=output_dir,
    evaluation_strategy="steps",
    weight_decay = 0.01,
    logging_steps = 500,
    eval_steps = 500,
    logging_dir='./logs/electra_ghosh',
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=4,
    seed=123,
    load_best_model_at_end=True,
    #save_total_limit=1,
    learning_rate = 2e-5
)

# %%
from transformers import EarlyStoppingCallback

trainer = Trainer(
    model=model,                         # the instantiated 🤗 Transformers model to be trained
    args= args,                  # training arguments, defined above
    train_dataset=train_dataset,         # training dataset
    eval_dataset=val_dataset,             # evaluation dataset
    tokenizer = tokenizer,
    compute_metrics = compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=25)]
)

trainer.train()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 39779
#   Num Epochs = 4
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 19892
#     <div>
#
#       <progress value='13000' max='19892' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [13000/19892 37:05 < 19:39, 5.84 it/s, Epoch 2/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.605800</td>
#       <td>0.378104</td>
#       <td>0.831847</td>
#       <td>0.084337</td>
#       <td>0.368421</td>
#       <td>0.137255</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.537600</td>
#       <td>0.697539</td>
#       <td>0.622293</td>
#       <td>0.067742</td>
#       <td>0.736842</td>
#       <td>0.124077</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.490800</td>
#       <td>0.781933</td>
#       <td>0.695541</td>
#       <td>0.086444</td>
#       <td>0.771930</td>
#       <td>0.155477</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.457800</td>
#       <td>0.726994</td>
#       <td>0.658599</td>
#       <td>0.080560</td>
#       <td>0.807018</td>
#       <td>0.146497</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.445800</td>
#       <td>0.654698</td>
#       <td>0.704459</td>
#       <td>0.095427</td>
#       <td>0.842105</td>
#       <td>0.171429</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.433800</td>
#       <td>0.401141</td>
#       <td>0.810191</td>
#       <td>0.122257</td>
#       <td>0.684211</td>
#       <td>0.207447</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.428700</td>
#       <td>0.519224</td>
#       <td>0.732484</td>
#       <td>0.095768</td>
#       <td>0.754386</td>
#       <td>0.169960</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.410700</td>
#       <td>0.640601</td>
#       <td>0.684076</td>
#       <td>0.085066</td>
#       <td>0.789474</td>
#       <td>0.153584</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.417500</td>
#       <td>0.569483</td>
#       <td>0.773248</td>
#       <td>0.111688</td>
#       <td>0.754386</td>
#       <td>0.194570</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.402700</td>
#       <td>0.522148</td>
#       <td>0.772611</td>
#       <td>0.113402</td>
#       <td>0.771930</td>
#       <td>0.197753</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.343700</td>
#       <td>0.648970</td>
#       <td>0.747771</td>
#       <td>0.104895</td>
#       <td>0.789474</td>
#       <td>0.185185</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.323800</td>
#       <td>0.646612</td>
#       <td>0.789172</td>
#       <td>0.125683</td>
#       <td>0.807018</td>
#       <td>0.217494</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.328800</td>
#       <td>0.762424</td>
#       <td>0.747771</td>
#       <td>0.108545</td>
#       <td>0.824561</td>
#       <td>0.191837</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.342600</td>
#       <td>0.798907</td>
#       <td>0.684713</td>
#       <td>0.097426</td>
#       <td>0.929825</td>
#       <td>0.176373</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.306100</td>
#       <td>0.818737</td>
#       <td>0.747134</td>
#       <td>0.111872</td>
#       <td>0.859649</td>
#       <td>0.197980</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.321700</td>
#       <td>0.488726</td>
#       <td>0.839490</td>
#       <td>0.155477</td>
#       <td>0.771930</td>
#       <td>0.258824</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.341900</td>
#       <td>0.778449</td>
#       <td>0.736943</td>
#       <td>0.109649</td>
#       <td>0.877193</td>
#       <td>0.194932</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.318900</td>
#       <td>0.729986</td>
#       <td>0.733121</td>
#       <td>0.109914</td>
#       <td>0.894737</td>
#       <td>0.195777</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.323200</td>
#       <td>1.121513</td>
#       <td>0.684713</td>
#       <td>0.097426</td>
#       <td>0.929825</td>
#       <td>0.176373</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.314000</td>
#       <td>1.001157</td>
#       <td>0.743312</td>
#       <td>0.113839</td>
#       <td>0.894737</td>
#       <td>0.201980</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.211500</td>
#       <td>0.885809</td>
#       <td>0.778981</td>
#       <td>0.130102</td>
#       <td>0.894737</td>
#       <td>0.227171</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.233800</td>
#       <td>0.742547</td>
#       <td>0.804459</td>
#       <td>0.142857</td>
#       <td>0.877193</td>
#       <td>0.245700</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.231500</td>
#       <td>0.652542</td>
#       <td>0.835032</td>
#       <td>0.163333</td>
#       <td>0.859649</td>
#       <td>0.274510</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.236700</td>
#       <td>0.969288</td>
#       <td>0.761783</td>
#       <td>0.121718</td>
#       <td>0.894737</td>
#       <td>0.214286</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.245000</td>
#       <td>0.872021</td>
#       <td>0.802548</td>
#       <td>0.139601</td>
#       <td>0.859649</td>
#       <td>0.240196</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.257600</td>
#       <td>0.852577</td>
#       <td>0.790446</td>
#       <td>0.136364</td>
#       <td>0.894737</td>
#       <td>0.236659</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-1000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-1000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-1000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-1000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-1500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-1500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-1500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-1500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-2000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-2000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-2000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-2000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-2500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-2500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-2500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-2500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-3000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-3000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-3000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-3000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-3500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-3500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-3500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-3500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-4000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-4000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-4000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-4000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-4500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-4500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-4500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-4500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-5000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-5000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-5000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-5000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-5500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-5500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-5500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-5500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-6000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-6000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-6000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-6000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-6500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-6500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-6500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-6500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-7000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-7000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-7000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-7000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-7500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-7500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-7500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-7500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-9000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-9000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-9000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-9000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-9500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-9500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-9500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-9500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-10000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-10000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-10000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-10000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-10500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-10500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-10500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-10500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-11000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-11000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-11000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-11000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-11500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-11500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-11500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-11500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-12000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-12000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-12000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-12000/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-12500
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-12500/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-12500/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-12500/added_tokens.json
# ***** Running Evaluation *****
#   Num examples = 1570
#   Batch size = 8
# Saving model checkpoint to ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-13000
# Configuration saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-13000/config.json
# Model weights saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-13000/special_tokens_map.json
# added tokens file saved in ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-13000/added_tokens.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-500 (score: 0.37810423970222473).
# Could not locate the best model at ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-500/pytorch_model.bin, if you are running a distributed training on multiple nodes, you should activate `--save_on_each_node`.
# TrainOutput(global_step=13000, training_loss=0.35816209528996396, metrics={'train_runtime': 2225.4602, 'train_samples_per_second': 71.498, 'train_steps_per_second': 8.938, 'total_flos': 4542340009737000.0, 'train_loss': 0.35816209528996396, 'epoch': 2.61})

# %%
X_test = list(df_test["Tweet"])
X_test_tokenized = tokenizer(X_test, padding=True, truncation=True, max_length=512)

# Create torch dataset
test_dataset = Dataset(X_test_tokenized,y_test)

# Load trained model
model_path = "./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8000"

model = ElectraForSequenceClassification.from_pretrained(model_path, num_labels=2)

# Define test trainer
test_trainer = Trainer(model)

# Make prediction
raw_pred, _, _ = test_trainer.predict(test_dataset)

# Preprocess raw predictions
y_pred = np.argmax(raw_pred, axis=1)
# Out:
# loading configuration file ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8000/config.json
# Model config ElectraConfig {
#   "_name_or_path": "google/electra-base-discriminator",
#   "architectures": [
#     "ElectraForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "embedding_size": 768,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "electra",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "problem_type": "single_label_classification",
#   "summary_activation": "gelu",
#   "summary_last_dropout": 0.1,
#   "summary_type": "first",
#   "summary_use_proj": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.19.4",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 30971
# }
#
# loading weights file ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8000/pytorch_model.bin
# All model checkpoint weights were used when initializing ElectraForSequenceClassification.
#
# All the weights of ElectraForSequenceClassification were initialized from the model checkpoint at ./drive/MyDrive/savedmodel_meta/ghosh_electra/checkpoint-8000.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use ElectraForSequenceClassification for predictions without further training.
# No `TrainingArguments` passed, using `output_dir=tmp_trainer`.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# ***** Running Prediction *****
#   Num examples = 1974
#   Batch size = 8
#     <div>
#
#       <progress value='247' max='247' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [247/247 00:26]
#     </div>

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test, y_pred,labels=[1,0])) #chkpoint8000
# Out:
#               precision    recall  f1-score   support
#
#            1       0.93      0.85      0.89       999
#            0       0.86      0.93      0.90       975
#
#     accuracy                           0.89      1974
#    macro avg       0.89      0.89      0.89      1974
# weighted avg       0.90      0.89      0.89      1974

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_test, y_pred,labels=[1,0]))#chkpoint 11500
# Out:
#               precision    recall  f1-score   support
#
#            1       0.91      0.88      0.89       999
#            0       0.88      0.91      0.89       975
#
#     accuracy                           0.89      1974
#    macro avg       0.89      0.89      0.89      1974
# weighted avg       0.89      0.89      0.89      1974

# %%
class_names = [1,0]

# %%
def show_confusion_matrix(confusion_matrix):
  hmap = sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Blues")
  hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
  hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=30, ha='right')
  plt.ylabel('True sentiment')
  plt.xlabel('Predicted sentiment');

cm = confusion_matrix(y_test, y_pred)
df_cm = pd.DataFrame(cm, index=class_names, columns=class_names)
show_confusion_matrix(df_cm)
